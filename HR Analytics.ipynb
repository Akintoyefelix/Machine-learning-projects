# %%
import pandas as pd,matplotlib.pyplot as plt,seaborn as sns,numpy as np

# %% [markdown]
# # Get insights on Employee Attrition and required procedure

# %%
data=pd.read_csv('Downloads/HR-Employee-Attrition.csv',skipinitialspace=True)

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.duplicated().any()
# Out:
# False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# #Analysis

# %%
data.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
data.YearsAtCompany.value_counts()
# Out:
# 5     196
# 1     171
# 3     128
# 2     127
# 10    120
# 4     110
# 7      90
# 9      82
# 8      80
# 6      76
# 0      44
# 11     32
# 20     27
# 13     24
# 15     20
# 14     18
# 22     15
# 12     14
# 21     14
# 18     13
# 16     12
# 19     11
# 17      9
# 24      6
# 33      5
# 25      4
# 26      4
# 31      3
# 32      3
# 27      2
# 36      2
# 29      2
# 23      2
# 37      1
# 40      1
# 34      1
# 30      1
# Name: YearsAtCompany, dtype: int64

# %%
data.DistanceFromHome.value_counts()
# Out:
# 2     211
# 1     208
# 10     86
# 9      85
# 3      84
# 7      84
# 8      80
# 5      65
# 4      64
# 6      59
# 16     32
# 11     29
# 24     28
# 23     27
# 29     27
# 15     26
# 18     26
# 26     25
# 25     25
# 20     25
# 28     23
# 19     22
# 14     21
# 12     20
# 17     20
# 22     19
# 13     19
# 21     18
# 27     12
# Name: DistanceFromHome, dtype: int64

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
correlation=data.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation,annot=True,cmap='coolwarm',linewidths=0.5)
# Out:
# <AxesSubplot:>

# %%
data.Attrition.value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
sns.countplot(data=data,x='Attrition')
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
# Number of employee that has left is less than the worker still in company

# %%
sns.countplot(data=data,x='YearsWithCurrManager',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsWithCurrManager', ylabel='count'>

# %%
# 1. workers that has spents some months with the manager has high Attrition
# 2. its observed that new employees can adapt to the manager leadership which leads to high attrition
# :. The manager needs to change its approach towards the newly employed,encouraging them,
#     reduce its strictness and promote efficiency and effectiveness

# %%
sns.countplot(data=data,x='YearsSinceLastPromotion',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='count'>

# %%
# 1.workers who has not been promoted betw 13,14,15 has low high Attrition,
#   Its might be they are considering retiring from duty there or they already reach the senior
#   management level in the organization.
# 2. workers who hasnt received any promotion for the last 7years are leaving due to inadequate 
#    advancement.
#There is high attrition for workers that has not being promoted for the last  2yrs

# %%
sns.countplot(data=data,x='YearsInCurrentRole',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='YearsInCurrentRole', ylabel='count'>

# %%
# 1. workers who spent 0,2,7 years in there current position has higer attrition
# 2. its observed and understood that most of the workers has experienced a stagnancy in their 
# position for seven years

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=data,x='YearsAtCompany',hue='Attrition')
plt.show()

# %% [markdown]
# <!-- workers in their year 1 in the company experience high Attrition rate
# Btw year 2,10 of work in the company,some number of peopleleft the company -->

# %%
# In the Year 1 in the company, there is high Attrition rate
# btw year 2 to 10 ,some numbers of people left the company.

# %%
data.WorkLifeBalance.value_counts()
# Out:
# 3    893
# 2    344
# 4    153
# 1     80
# Name: WorkLifeBalance, dtype: int64

# %%
sns.countplot(data=data,x='WorkLifeBalance',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='count'>

# %%
# Employees whose worklife btw 2 & 3 has high Attrition rate
# :.seems the workers are not pleased with the load of work they did
#     for 1 to 4 years of the workspan.

# %%
sns.countplot(data=data,x='TrainingTimesLastYear',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='TrainingTimesLastYear', ylabel='count'>

# %%
# The number of trainning time also cause the Attrition, its observed that the number
# of employees who trained more the two times last years has high Attrition rate
# :. The number of training per year should be put minimum

# %%
data.TotalWorkingYears.value_counts()
# Out:
# 10    202
# 6     125
# 8     103
# 9      96
# 5      88
# 7      81
# 1      81
# 4      63
# 12     48
# 3      42
# 15     40
# 16     37
# 11     36
# 13     36
# 21     34
# 17     33
# 2      31
# 14     31
# 20     30
# 18     27
# 19     22
# 23     22
# 22     21
# 24     18
# 25     14
# 28     14
# 26     14
# 0      11
# 29     10
# 31      9
# 32      9
# 30      7
# 33      7
# 27      7
# 36      6
# 34      5
# 37      4
# 35      3
# 40      2
# 38      1
# Name: TotalWorkingYears, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(data=data,x='TotalWorkingYears',hue='Attrition')
# Out:
# <AxesSubplot:xlabel='TotalWorkingYears', ylabel='count'>

# %%
# Workers whose total working year equals one has a higher frequency of Attrition,
# :.There should be measure inplace to appreciate and encourage the workers

# %%
data.RelationshipSatisfaction.value_counts()
# Out:
# 3    459
# 4    432
# 2    303
# 1    276
# Name: RelationshipSatisfaction, dtype: int64

# %%
sns.set_style('darkgrid')
sns.countplot(data=data,x='RelationshipSatisfaction', hue='Attrition')
# Out:
# <AxesSubplot:xlabel='RelationshipSatisfaction', ylabel='count'>

# %%
# we have less the 50 workers with 1% relationship satisfactory that left the company
# There is high attrition for workers who relationship satisfaction falls btw 3 and 4

# %%
data.PerformanceRating.value_counts()
# Out:
# 3    1244
# 4     226
# Name: PerformanceRating, dtype: int64

# %%
sns.countplot(data=data,x='PerformanceRating',hue='Attrition')
plt.grid(False)

# %%
# The workers performance rating has high effect on the Attrition rate

# %%
data.EducationField.value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=data,x='EducationField',hue='Attrition')
plt.grid('whitegrid')

# %%
data.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
data[(data['Department']=='Sales') & (data['Attrition']=='Yes')]
# Out:
#       Age Attrition     BusinessTravel  DailyRate Department  \
# 0      41       Yes      Travel_Rarely       1102      Sales
# 21     36       Yes      Travel_Rarely       1218      Sales
# 33     39       Yes      Travel_Rarely        895      Sales
# 36     50       Yes      Travel_Rarely        869      Sales
# 89     46       Yes      Travel_Rarely        669      Sales
# ...   ...       ...                ...        ...        ...
# 1395   31       Yes  Travel_Frequently        754      Sales
# 1396   53       Yes      Travel_Rarely       1168      Sales
# 1438   23       Yes  Travel_Frequently        638      Sales
# 1452   50       Yes  Travel_Frequently        878      Sales
# 1461   50       Yes      Travel_Rarely        410      Sales
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 0                    1          2     Life Sciences              1
# 21                   9          4     Life Sciences              1
# ...

# %% [markdown]
# 1. In the department of Human Resources 12 employees left the company while 51 empolees still
# works for the company
#
# 2. In Research department we have 133 numbers of Attrition and 828 working employees
#
# 3.In sales dept 92 Employees left and 354 still working.
#
# :. In a nutshell out of all the three department we infer that research dept has
#     the highest number of worker in the company,and also has the highest attrition rate.
#
#     -all the department has an attrition rate,neither the departments encourages
#     the employee.
#         _the department can be sub_grouped to activate the potential employee
#         _this way there will be room for

# %%
An=data.groupby(['Attrition','EducationField']).agg(count_Dept=('Department','count'),
                                                count_Distance=('DistanceFromHome', 'count')).reset_index()
An
# Out:
#    Attrition    EducationField  count_Dept  count_Distance
# 0         No   Human Resources          20              20
# 1         No     Life Sciences         517             517
# 2         No         Marketing         124             124
# 3         No           Medical         401             401
# 4         No             Other          71              71
# 5         No  Technical Degree         100             100
# 6        Yes   Human Resources           7               7
# 7        Yes     Life Sciences          89              89
# 8        Yes         Marketing          35              35
# 9        Yes           Medical          63              63
# 10       Yes             Other          11              11
# 11       Yes  Technical Degree          32              32

# %%
(data['EducationField']=='Life Sciences').count()
# Out:
# 1470

# %%
data[(data['Department']=='Research & Development') & (data['Attrition']=='No')].count()
# Out:
# Age                         828
# Attrition                   828
# BusinessTravel              828
# DailyRate                   828
# Department                  828
# DistanceFromHome            828
# Education                   828
# EducationField              828
# EmployeeCount               828
# EmployeeNumber              828
# EnvironmentSatisfaction     828
# Gender                      828
# HourlyRate                  828
# JobInvolvement              828
# JobLevel                    828
# JobRole                     828
# JobSatisfaction             828
# MaritalStatus               828
# MonthlyIncome               828
# MonthlyRate                 828
# NumCompaniesWorked          828
# Over18                      828
# OverTime                    828
# PercentSalaryHike           828
# PerformanceRating           828
# RelationshipSatisfaction    828
# StandardHours               828
# StockOptionLevel            828
# TotalWorkingYears           828
# ...

# %%
pip install pandoc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.
